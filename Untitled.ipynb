# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: notebook in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (6.5.7)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 7)) (6.17.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 10)) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 11)) (0.13.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 15)) (1.6.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 16)) (3.2.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 17)) (4.6.0)
# Collecting catboost (from -r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 18))
#   Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Collecting optuna (from -r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 20))
#   Downloading optuna-4.8.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 22)) (0.14.1)
# Collecting mlflow (from -r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27))
#   Downloading mlflow-3.12.0-py3-none-any.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 8.0 MB/s eta 0:00:00
# Collecting pyngrok (from -r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 30))
#   Downloading pyngrok-8.1.2-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 33)) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 3)) (2025.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (6.5.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (26.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (25.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.12/dist-packages (from notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.12/dist-packages (from notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (5.9.1)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.12/dist-packages (from notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (7.4.9)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.12/dist-packages (from notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (7.17.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.12/dist-packages (from notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (0.24.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 7)) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 7)) (7.34.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 7)) (0.2.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 7)) (26.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 7)) (5.9.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 10)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 10)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 10)) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 10)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 10)) (3.3.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 15)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 15)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 15)) (3.6.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 16)) (2.27.5)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 18)) (0.21)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 18)) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 18)) (1.17.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 20)) (1.18.4)
# Collecting colorlog (from optuna->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 20))
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 20)) (2.0.48)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 20)) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 20)) (6.0.3)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 22)) (0.1.5)
# Collecting mlflow-skinny==3.12.0 (from mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27))
#   Downloading mlflow_skinny-3.12.0-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 8.8 MB/s eta 0:00:00
# Collecting mlflow-tracing==3.12.0 (from mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27))
#   Downloading mlflow_tracing-3.12.0-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27))
#   Downloading flask_cors-6.0.2-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.12/dist-packages (from mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (3.1.3)
# Requirement already satisfied: aiohttp<4 in /usr/local/lib/python3.12/dist-packages (from mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (3.13.4)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (43.0.3)
# Collecting docker<8,>=4.0.0 (from mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27))
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27))
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<26 (from mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27))
#   Downloading gunicorn-25.3.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting huey<3,>=2.5.4 (from mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27))
#   Downloading huey-2.6.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pyarrow<24,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (18.1.0)
# Collecting skops<1 (from mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27))
#   Downloading skops-0.14.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: cachetools<8,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (8.3.1)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (3.1.2)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27))
#   Downloading databricks_sdk-0.107.0-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: fastapi<1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (0.135.2)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (3.1.46)
# Requirement already satisfied: importlib_metadata!=4.7.0,<10,>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (1.38.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (1.38.0)
# Requirement already satisfied: protobuf<8,>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (5.29.6)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (2.12.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (2.32.4)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (0.5.5)
# Requirement already satisfied: starlette<1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (0.52.1)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (0.42.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (1.23.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 20)) (1.3.10)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography<47,>=43.0.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (2.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from docker<8,>=4.0.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (2.5.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (3.1.7)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27))
#   Downloading graphql_core-3.2.8-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27))
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 7)) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 7))
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 7)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 7)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 7)) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 7)) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 7)) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client<8,>=5.3.4->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.6.1->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (4.9.4)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (4.26.0)
# Requirement already satisfied: prettytable>=3.9 in /usr/local/lib/python3.12/dist-packages (from skops<1->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (3.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 20)) (3.3.2)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.12/dist-packages (from terminado>=0.8.3->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (25.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 18)) (9.1.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography<47,>=43.0.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (3.0)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.12/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (2.47.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1->mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1->mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (0.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata!=4.7.0,<10,>=3.7.0->mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (3.23.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 7)) (0.8.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (0.30.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (2.14.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (0.59b0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable>=3.9->skops<1->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (0.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (2.41.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (2026.2.25)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette<1->mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (4.13.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn<1->mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (0.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (2.8.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (5.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (4.9.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (1.9.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (0.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.12.0->mlflow->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 27)) (0.6.3)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->-r /content/drive/MyDrive/real_time_fraud_detection/requirements.txt (line 6)) (1.4.0)
# Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl (97.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 33.0 MB/s eta 0:00:00:00:0100:01
# Downloading optuna-4.8.0-py3-none-any.whl (419 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 53.0 MB/s eta 0:00:00
# Downloading mlflow-3.12.0-py3-none-any.whl (10.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 182.9 MB/s eta 0:00:00 0:00:01
# Downloading mlflow_skinny-3.12.0-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 155.0 MB/s eta 0:00:00
# Downloading mlflow_tracing-3.12.0-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 111.7 MB/s eta 0:00:00
# Downloading pyngrok-8.1.2-py3-none-any.whl (25 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 26.6 MB/s eta 0:00:00
# Downloading flask_cors-6.0.2-py3-none-any.whl (13 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 19.3 MB/s eta 0:00:00
# Downloading gunicorn-25.3.0-py3-none-any.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.4/208.4 kB 34.3 MB/s eta 0:00:00
# Downloading huey-2.6.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 13.8 MB/s eta 0:00:00
# Downloading skops-0.14.0-py3-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.2/132.2 kB 25.3 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading databricks_sdk-0.107.0-py3-none-any.whl (887 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.7/887.7 kB 85.4 MB/s eta 0:00:00
# Downloading graphql_core-3.2.8-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 34.4 MB/s eta 0:00:00
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 171.9 MB/s eta 0:00:00
# Installing collected packages: huey, pyngrok, jedi, gunicorn, graphql-core, colorlog, graphql-relay, docker, skops, optuna, graphene, Flask-CORS, databricks-sdk, catboost, mlflow-tracing, mlflow-skinny, mlflow
# Successfully installed Flask-CORS-6.0.2 catboost-1.2.10 colorlog-6.10.1 databricks-sdk-0.107.0 docker-7.1.0 graphene-3.4.3 graphql-core-3.2.8 graphql-relay-3.2.0 gunicorn-25.3.0 huey-2.6.0 jedi-0.20.0 mlflow-3.12.0 mlflow-skinny-3.12.0 mlflow-tracing-3.12.0 optuna-4.8.0 pyngrok-8.1.2 skops-0.14.0

# %%
# %load_ext cudf.pandas    
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns',None)  #here we are setting the option of pandas to display all the columns
import seaborn as sns
from sklearn.preprocessing import RobustScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression, Ridge
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from lightgbm import LGBMClassifier
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
from sklearn.metrics import (classification_report, roc_auc_score,
                             average_precision_score, precision_recall_curve,
                             recall_score, precision_score, f1_score)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_427/4185150316.py in <cell line: 0>()
# ----> 1 get_ipython().run_line_magic('load_ext', 'cudf.pandas     #enabling GPU-accelerated pandas with cuDF')
#       2 import numpy as np
#       3 import pandas as pd
#       4 import matplotlib.pyplot as plt
#       5 pd.set_option('display.max_columns',None)  #here we are setting the option of pandas to display all the columns
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-57> in load_ext(self, module_str)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/extension.py in load_ext(self, module_str)
#      31         if not module_str:
#      32             raise UsageError('Missing module name.')
# ---> 33         res = self.shell.extension_manager.load_extension(module_str)
#      34
#      35         if res == 'already loaded':
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/extensions.py in load_extension(self, module_str)
#      78             if module_str not in sys.modules:
#      79                 with prepended_to_syspath(self.ipython_extension_dir):
# ---> 80                     mod = import_module(module_str)
#      81                     if mod.__file__.startswith(self.ipython_extension_dir):
#      82                         print(("Loading extensions from {dir} is deprecated. "
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      88                 break
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#      92
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'cudf.pandas     #enabling GPU-accelerated pandas with cuDF'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
df = pd.read_csv('/content/drive/MyDrive/real_time_fraud_detection/pay_sim.csv')
df.head()
